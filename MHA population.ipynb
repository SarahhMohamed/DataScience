# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/Users/imacstore/Desktop/MHA Population Report.csv")

# %%
df.head(20)
# Out:
#     Census Year    District Taluka   Town/Village  No. of households  \
# 0          2011  AHMADNAGAR  AKOLA     ABIT KHIND                201
# 1          2011  AHMADNAGAR  AKOLA           AGAR                 37
# 2          2011  AHMADNAGAR  AKOLA    AGASTINAGAR                357
# 3          2011  AHMADNAGAR  AKOLA          AKOLA               3861
# 4          2011  AHMADNAGAR  AKOLA          AMBAD                529
# 5          2011  AHMADNAGAR  AKOLA     AMBEVANGAN                194
# 6          2011  AHMADNAGAR  AKOLA         AMBHOL                331
# 7          2011  AHMADNAGAR  AKOLA    AMBIKANAGAR                120
# 8          2011  AHMADNAGAR  AKOLA          AMBIT                156
# 9          2011  AHMADNAGAR  AKOLA      AURANGPUR                205
# 10         2011  AHMADNAGAR  AKOLA   BABHUL WANDI                300
# 11         2011  AHMADNAGAR  AKOLA          BADGI                109
# 12         2011  AHMADNAGAR  AKOLA      BAHIRWADI                258
# 13         2011  AHMADNAGAR  AKOLA        BALTHAN                205
# 14         2011  AHMADNAGAR  AKOLA      BARAVWADI                328
# 15         2011  AHMADNAGAR  AKOLA           BARI                201
# 16         2011  AHMADNAGAR  AKOLA        BELAPUR                759
# 17         2011  AHMADNAGAR  AKOLA    BHANDARDARA                393
# 18         2011  AHMADNAGAR  AKOLA  BHOJADARAWADI                 81
# 19         2011  AHMADNAGAR  AKOLA      BHOLEWADI                103
#
#     Total population  Total male population  Total female population  \
# 0                732                    359                      373
# 1                247                    162                       85
# 2               1536                    799                      737
# 3              18278                   9381                     8897
# 4               2590                   1352                     1238
# 5                765                    378                      387
# 6               1434                    741                      693
# 7                645                    318                      327
# 8                692                    328                      364
# 9               1004                    510                      494
# 10              1477                    744                      733
# 11               478                    237                      241
# 12              1052                    547                      505
# 13              1072                    545                      527
# 14              1509                    747                      762
# 15              1073                    561                      512
# 16              3166                   1530                     1636
# 17              1765                    883                      882
# 18               387                    189                      198
# 19               541                    282                      259
#
#     Total 0 to 6 year children  Male 0 to 6 year children  ...  \
# 0                           73                         36  ...
# 1                           27                         15  ...
# 2                          178                         97  ...
# 3                         2066                       1101  ...
# 4                          333                        189  ...
# 5                           96                         46  ...
# 6                          143                         86  ...
# 7                           97                         50  ...
# 8                          129                         66  ...
# 9                          108                         46  ...
# 10                         224                        110  ...
# 11                          37                         25  ...
# 12                          91                         50  ...
# 13                         172                         84  ...
# 14                         174                         82  ...
# 15                         116                         48  ...
# 16                         352                        174  ...
# 17                         180                         96  ...
# 18                          43                         22  ...
# 19                          37                         19  ...
#
#     Female literates  Total iliterates  Male iliterates  Female iliterates  \
# 0                175             313.0            115.0              198.0
# 1                 53              58.0             26.0               32.0
# 2                467             462.0            192.0              270.0
# 3               6437            4400.0           1940.0             2460.0
# 4                743             845.0            350.0              495.0
# 5                134             395.0            142.0              253.0
# 6                400             470.0            177.0              293.0
# 7                167             254.0             94.0              160.0
# 8                121             410.0            167.0              243.0
# 9                321             280.0            107.0              173.0
# 10               357             618.0            242.0              376.0
# 11               148             143.0             50.0               93.0
# 12               312             300.0            107.0              193.0
# 13               229             495.0            197.0              298.0
# 14               417             535.0            190.0              345.0
# 15               275             352.0            115.0              237.0
# 16               940            1087.0            391.0              696.0
# 17               576             505.0            199.0              306.0
# 18                98             165.0             65.0              100.0
# 19               236              53.0             30.0               23.0
#
#     Total main workers  Male main workers  Female main workers  \
# 0                  424                204                  220
# 1                  106                 58                   48
# 2                  787                439                  348
# 3                 6688               4599                 2089
# 4                 1491                763                  728
# 5                  537                259                  278
# 6                  834                426                  408
# 7                  308                161                  147
# 8                    6                  5                    1
# 9                  544                275                  269
# 10                 785                396                  389
# 11                 260                137                  123
# 12                 610                313                  297
# 13                 548                276                  272
# 14                 481                268                  213
# 15                 620                312                  308
# 16                1462                778                  684
# 17                 713                417                  296
# 18                 222                110                  112
# 19                 317                164                  153
#
#     Total non workers  Male non workers  Female non workers
# 0                 285               143                 142
# 1                 140               103                  37
# 2                 681               332                 349
# 3               10937              4422                6515
# 4                1083               580                 503
# 5                 222               116                 106
# 6                 591               312                 279
# 7                 329               155                 174
# 8                 206                97                 109
# 9                 440               221                 219
# 10                679               345                 334
# 11                218               100                 118
# 12                395               210                 185
# 13                510               262                 248
# 14                773               377                 396
# 15                435               241                 194
# 16               1615               709                 906
# 17               1036               457                 579
# 18                163                78                  85
# 19                205               112                  93
#
# [20 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Census Year', 'District', 'Taluka', 'Town/Village',
#        'No. of households', 'Total population', 'Total male population',
#        'Total female population', 'Total 0 to 6 year children',
#        'Male 0 to 6 year children', 'Female 0 to 6 year children',
#        'Total SC population', 'Male SC population', 'Female SC population',
#        'Total ST population', 'Male ST population', 'Female ST population',
#        'Total literates', 'Male literates', 'Female literates',
#        'Total iliterates', 'Male iliterates', 'Female iliterates',
#        'Total main workers', 'Male main workers', 'Female main workers',
#        'Total non workers', 'Male non workers', 'Female non workers'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

df
# Out:
#         Census Year    District    Taluka Town/Village  No. of households  \
# 0              2011  AHMADNAGAR     AKOLA   ABIT KHIND                201
# 1              2011  AHMADNAGAR     AKOLA         AGAR                 37
# 2              2011  AHMADNAGAR     AKOLA  AGASTINAGAR                357
# 3              2011  AHMADNAGAR     AKOLA        AKOLA               3861
# 4              2011  AHMADNAGAR     AKOLA        AMBAD                529
# ...             ...         ...       ...          ...                ...
# 132310         1991    YAVATMAL  YAVATMAL     YELABARA                489
# 132311         1991    YAVATMAL  YAVATMAL        YERAD                234
# 132312         1991    YAVATMAL  YAVATMAL       YEVATI                103
# 132313         1991    YAVATMAL  YAVATMAL         ZOLA                  0
# 132314         1991    YAVATMAL  YAVATMAL         ZULI                124
#
#         Total population  Total male population  Total female population  \
# 0                    732                    359                      373
# 1                    247                    162                       85
# 2                   1536                    799                      737
# 3                  18278                   9381                     8897
# 4                   2590                   1352                     1238
# ...                  ...                    ...                      ...
# 132310              2381                   1237                     1144
# 132311              1162                    588                      574
# 132312               461                    232                      229
# 132313                 0                      0                        0
# 132314               592                    306                      286
#
#         Total 0 to 6 year children  Male 0 to 6 year children  \
# 0                               73                         36
# 1                               27                         15
# 2                              178                         97
# 3                             2066                       1101
# 4                              333                        189
# ...                            ...                        ...
# 132310                         364                        175
# 132311                         189                         94
# 132312                          77                         37
# 132313                           0                          0
# 132314                          98                         52
#
#         Female 0 to 6 year children  Total SC population  Male SC population  \
# 0                                37                   12                   5
# 1                                12                    9                   4
# 2                                81                  157                  84
# 3                               965                 1496                 742
# 4                               144                   87                  45
# ...                             ...                  ...                 ...
# 132310                          189                  270                 152
# 132311                           95                  245                 125
# 132312                           40                   23                   9
# 132313                            0                    0                   0
# 132314                           46                   15                   8
#
#         Female SC population  Total ST population  Male ST population  \
# 0                          7                  695                 344
# 1                          5                  121                  99
# 2                         73                   59                  35
# 3                        754                 1503                 750
# 4                         42                  425                 219
# ...                      ...                  ...                 ...
# 132310                   118                  671                 341
# 132311                   120                  322                 168
# 132312                    14                  111                  57
# 132313                     0                    0                   0
# 132314                     7                   67                  35
#
#         Female ST population  Total literates  Male literates  \
# 0                        351              419             244
# 1                         22              189             136
# 2                         24             1074             607
# 3                        753            13878            7441
# 4                        206             1745            1002
# ...                      ...              ...             ...
# 132310                   330             1185             768
# 132311                   154              427             278
# 132312                    54              163             110
# 132313                     0                0               0
# 132314                    32              261             176
#
#         Female literates  Total iliterates  Male iliterates  \
# 0                    175             313.0            115.0
# 1                     53              58.0             26.0
# 2                    467             462.0            192.0
# 3                   6437            4400.0           1940.0
# 4                    743             845.0            350.0
# ...                  ...               ...              ...
# 132310               417               NaN              NaN
# 132311               149               NaN              NaN
# 132312                53               NaN              NaN
# 132313                 0               NaN              NaN
# 132314                85               NaN              NaN
#
#         Female iliterates  Total main workers  Male main workers  \
# 0                   198.0                 424                204
# 1                    32.0                 106                 58
# 2                   270.0                 787                439
# 3                  2460.0                6688               4599
# 4                   495.0                1491                763
# ...                   ...                 ...                ...
# 132310                NaN                1111                643
# 132311                NaN                 581                302
# 132312                NaN                 246                143
# 132313                NaN                   0                  0
# 132314                NaN                 341                185
#
#         Female main workers  Total non workers  Male non workers  \
# 0                       220                285               143
# 1                        48                140               103
# 2                       348                681               332
# 3                      2089              10937              4422
# 4                       728               1083               580
# ...                     ...                ...               ...
# 132310                  468               1249               588
# 132311                  279                559               283
# 132312                  103                204                87
# 132313                    0                  0                 0
# 132314                  156                242               120
#
#         Female non workers
# 0                      142
# 1                       37
# 2                      349
# 3                     6515
# 4                      503
# ...                    ...
# 132310                 661
# 132311                 276
# 132312                 117
# 132313                   0
# 132314                 122
#
# [132315 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132315 entries, 0 to 132314
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Census Year                  132315 non-null  int64
#  1   District                     132315 non-null  object
#  2   Taluka                       132299 non-null  object
#  3   Town/Village                 131279 non-null  object
#  4   No. of households            132315 non-null  int64
#  5   Total population             132315 non-null  int64
#  6   Total male population        132315 non-null  int64
#  7   Total female population      132315 non-null  int64
#  8   Total 0 to 6 year children   132315 non-null  int64
#  9   Male 0 to 6 year children    132315 non-null  int64
#  10  Female 0 to 6 year children  132315 non-null  int64
#  11  Total SC population          132315 non-null  int64
#  12  Male SC population           132315 non-null  int64
#  13  Female SC population         132315 non-null  int64
#  14  Total ST population          132315 non-null  int64
#  15  Male ST population           132315 non-null  int64
#  16  Female ST population         132315 non-null  int64
#  17  Total literates              132315 non-null  int64
#  18  Male literates               132315 non-null  int64
#  19  Female literates             132315 non-null  int64
#  20  Total iliterates             82968 non-null   float64
#  21  Male iliterates              82968 non-null   float64
#  22  Female iliterates            82968 non-null   float64
#  23  Total main workers           132315 non-null  int64
#  24  Male main workers            132315 non-null  int64
#  25  Female main workers          132315 non-null  int64
#  26  Total non workers            132315 non-null  int64
#  27  Male non workers             132315 non-null  int64
#  28  Female non workers           132315 non-null  int64
# dtypes: float64(3), int64(23), object(3)
# memory usage: 29.3+ MB

# %%
df.isnull().sum()
# Out:
# Census Year                        0
# District                           0
# Taluka                            16
# Town/Village                    1036
# No. of households                  0
# Total population                   0
# Total male population              0
# Total female population            0
# Total 0 to 6 year children         0
# Male 0 to 6 year children          0
# Female 0 to 6 year children        0
# Total SC population                0
# Male SC population                 0
# Female SC population               0
# Total ST population                0
# Male ST population                 0
# Female ST population               0
# Total literates                    0
# Male literates                     0
# Female literates                   0
# Total iliterates               49347
# Male iliterates                49347
# Female iliterates              49347
# Total main workers                 0
# Male main workers                  0
# Female main workers                0
# Total non workers                  0
# Male non workers                   0
# Female non workers                 0
# dtype: int64

# %%
#cols=['Total iliterates','Male iliterates','Female iliterates']
mode=df['Total iliterates'].mode()
df['Total iliterates'] =  df['Total iliterates'].fillna(mode[0])

# %%
#cols=['Total iliterates','Male iliterates','Female iliterates']
mode=df['Male iliterates'].mode()
df['Male iliterates'] =  df['Male iliterates'].fillna(mode[0])

# %%
#cols=['Total iliterates','Male iliterates','Female iliterates']
mode=df['Female iliterates'].mode()
df['Female iliterates'] =  df['Female iliterates'].fillna(mode[0])

# %%
df.isnull().sum()
# Out:
# Census Year                       0
# District                          0
# Taluka                           16
# Town/Village                   1036
# No. of households                 0
# Total population                  0
# Total male population             0
# Total female population           0
# Total 0 to 6 year children        0
# Male 0 to 6 year children         0
# Female 0 to 6 year children       0
# Total SC population               0
# Male SC population                0
# Female SC population              0
# Total ST population               0
# Male ST population                0
# Female ST population              0
# Total literates                   0
# Male literates                    0
# Female literates                  0
# Total iliterates                  0
# Male iliterates                   0
# Female iliterates                 0
# Total main workers                0
# Male main workers                 0
# Female main workers               0
# Total non workers                 0
# Male non workers                  0
# Female non workers                0
# dtype: int64

# %%
df = df.dropna(subset=['Taluka', 'Town/Village'])

# %%
df.isnull().sum()
# Out:
# Census Year                    0
# District                       0
# Taluka                         0
# Town/Village                   0
# No. of households              0
# Total population               0
# Total male population          0
# Total female population        0
# Total 0 to 6 year children     0
# Male 0 to 6 year children      0
# Female 0 to 6 year children    0
# Total SC population            0
# Male SC population             0
# Female SC population           0
# Total ST population            0
# Male ST population             0
# Female ST population           0
# Total literates                0
# Male literates                 0
# Female literates               0
# Total iliterates               0
# Male iliterates                0
# Female iliterates              0
# Total main workers             0
# Male main workers              0
# Female main workers            0
# Total non workers              0
# Male non workers               0
# Female non workers             0
# dtype: int64

# %%
df.describe()
# Out:
#          Census Year  No. of households  Total population  \
# count  131265.000000       1.312650e+05      1.312650e+05
# mean     2000.481583       7.646644e+02      3.858935e+03
# std         8.254554       8.846190e+03      4.082773e+04
# min      1991.000000       0.000000e+00      0.000000e+00
# 25%      1991.000000       1.030000e+02      4.990000e+02
# 50%      2001.000000       1.940000e+02      9.540000e+02
# 75%      2011.000000       3.630000e+02      1.794000e+03
# max      2011.000000       2.105604e+06      9.356962e+06
#
#        Total male population  Total female population  \
# count           1.312650e+05             1.312650e+05
# mean            2.002583e+03             1.856352e+03
# std             2.165589e+04             1.918662e+04
# min             0.000000e+00             0.000000e+00
# 25%             2.490000e+02             2.480000e+02
# 50%             4.810000e+02             4.710000e+02
# 75%             9.140000e+02             8.810000e+02
# max             5.031323e+06             4.325639e+06
#
#        Total 0 to 6 year children  Male 0 to 6 year children  \
# count               131265.000000              131265.000000
# mean                   590.495646                 306.475412
# std                   5050.033604                2629.392607
# min                      0.000000                   0.000000
# 25%                     73.000000                  38.000000
# 50%                    145.000000                  75.000000
# 75%                    275.000000                 143.000000
# max                 930884.000000              486696.000000
#
#        Female 0 to 6 year children  Total SC population  Male SC population  \
# count                131265.000000        131265.000000       131265.000000
# mean                    284.020234           458.848040          235.891593
# std                    2421.117062          4536.725279         2331.213943
# min                       0.000000             0.000000            0.000000
# 25%                      35.000000             4.000000            2.000000
# 50%                      70.000000            74.000000           37.000000
# 75%                     132.000000           236.000000          120.000000
# max                  444188.000000        583302.000000       300291.000000
#
#        Female SC population  Total ST population  Male ST population  \
# count         131265.000000        131265.000000       131265.000000
# mean             222.956447           269.744243          137.561300
# std             2206.010341          1255.974209          647.894642
# min                0.000000             0.000000            0.000000
# 25%                2.000000             0.000000            0.000000
# 50%               36.000000            40.000000           21.000000
# 75%              116.000000           237.000000          120.000000
# max           283011.000000        185281.000000        94638.000000
#
#        Female ST population  Total literates  Male literates  \
# count         131265.000000     1.312650e+05    1.312650e+05
# mean             132.182943     2.469655e+03    1.431941e+03
# std              608.459033     3.115924e+04    1.738868e+04
# min                0.000000     0.000000e+00    0.000000e+00
# 25%                0.000000     2.440000e+02    1.490000e+02
# 50%               20.000000     5.150000e+02    3.100000e+02
# 75%              116.000000     1.046000e+03    6.190000e+02
# max            90643.000000     7.575485e+06    4.223029e+06
#
#        Female literates  Total iliterates  Male iliterates  Female iliterates  \
# count      1.312650e+05      1.312650e+05    131265.000000      131265.000000
# mean       1.037714e+03      5.387464e+02       207.885141         315.039439
# std        1.379006e+04      6.964140e+03      3132.440966        3837.687833
# min        0.000000e+00      0.000000e+00         0.000000           0.000000
# 25%        9.000000e+01      2.020000e+02        48.000000         111.000000
# 50%        2.040000e+02      2.020000e+02        62.000000         111.000000
# 75%        4.310000e+02      4.540000e+02       176.000000         277.000000
# max        3.352456e+06      1.781477e+06    808294.000000      973183.000000
#
#        Total main workers  Male main workers  Female main workers  \
# count        1.312650e+05       1.312650e+05        131265.000000
# mean         1.315099e+03       9.692457e+02           345.853373
# std          1.404904e+04       1.136051e+04          2740.708686
# min          0.000000e+00       0.000000e+00             0.000000
# 25%          2.020000e+02       1.210000e+02            71.000000
# 50%          4.120000e+02       2.410000e+02           167.000000
# 75%          7.900000e+02       4.650000e+02           325.000000
# max          3.515922e+06       2.811481e+06        704441.000000
#
#        Total non workers  Male non workers  Female non workers
# count       1.312650e+05      1.312650e+05        1.312650e+05
# mean        2.412210e+03      9.885399e+02        1.423670e+03
# std         2.616693e+04      9.949207e+03        1.622610e+04
# min         0.000000e+00      0.000000e+00        0.000000e+00
# 25%         2.250000e+02      1.070000e+02        1.150000e+02
# 50%         4.510000e+02      2.130000e+02        2.350000e+02
# 75%         8.820000e+02      4.140000e+02        4.710000e+02
# max         5.621941e+06      2.087001e+06        3.534940e+06

# %%
df.shape
# Out:
# (131265, 29)

# %%
#Drop duplicates
df.drop_duplicates(keep=False, inplace=True)

# %%
sns.boxplot(df['Total population'])
# Out:
# <Axes: >

# %%
# calculate the IQR for the column
q1 = df['Total population'].quantile(0.25)
q3 = df['Total population'].quantile(0.75)
iqr = q3 - q1

# identify and remove outliers
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(df['Total population'] >= lower_bound) & (df['Total population'] <= upper_bound)]

# %%
sns.boxplot(df['No. of households'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total male population'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total female population'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total 0 to 6 year children'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male 0 to 6 year children'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female 0 to 6 year children'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total ST population'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male ST population'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female ST population'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total literates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male literates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female literates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total iliterates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male iliterates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female iliterates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male main workers'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total main workers'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female main workers'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Total non workers'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Male non workers'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Female non workers'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#          Census Year  No. of households  Total population  \
# count  117439.000000      117439.000000     117439.000000
# mean     2000.826889         211.985593       1040.530352
# std         8.179751         160.855155        790.998008
# min      1991.000000           0.000000          0.000000
# 25%      1991.000000          95.000000        457.000000
# 50%      2001.000000         172.000000        843.000000
# 75%      2011.000000         291.000000       1434.000000
# max      2011.000000        1183.000000       3737.000000
#
#        Total male population  Total female population  \
# count          117439.000000            117439.000000
# mean              528.257862               512.272490
# std               407.000640               385.886966
# min                 0.000000                 0.000000
# 25%               228.000000               228.000000
# 50%               425.000000               417.000000
# 75%               729.000000               706.000000
# max              2571.000000              2000.000000
#
#        Total 0 to 6 year children  Male 0 to 6 year children  \
# count               117439.000000              117439.000000
# mean                   158.871882                  82.414854
# std                    125.502255                  65.515148
# min                      0.000000                   0.000000
# 25%                     67.000000                  34.000000
# 50%                    128.000000                  66.000000
# 75%                    219.000000                 114.000000
# max                    982.000000                 510.000000
#
#        Female 0 to 6 year children  Total SC population  Male SC population  \
# count                117439.000000        117439.000000       117439.000000
# mean                     76.457029           116.429721           59.369426
# std                      60.823726           158.299394           81.118240
# min                       0.000000             0.000000            0.000000
# 25%                      32.000000             1.000000            1.000000
# 50%                      61.000000            54.000000           27.000000
# 75%                     105.000000           171.000000           87.000000
# max                     516.000000          2020.000000         1027.000000
#
#        Female SC population  Total ST population  Male ST population  \
# count         117439.000000        117439.000000       117439.000000
# mean              57.060295           167.318829           84.407675
# std               77.466676           328.732576          165.368461
# min                0.000000             0.000000            0.000000
# 25%                0.000000             0.000000            0.000000
# 50%               26.000000            28.000000           14.000000
# 75%               84.000000           184.000000           93.000000
# max              993.000000          3712.000000         1892.000000
#
#        Female ST population  Total literates  Male literates  \
# count         117439.000000    117439.000000   117439.000000
# mean              82.911154       588.752893      349.545483
# std              163.865647       505.925507      291.987476
# min                0.000000         0.000000        0.000000
# 25%                0.000000       219.000000      135.000000
# 50%               14.000000       448.000000      271.000000
# 75%               91.000000       817.000000      485.000000
# max             1887.000000      3197.000000     2135.000000
#
#        Female literates  Total iliterates  Male iliterates  Female iliterates  \
# count     117439.000000     117439.000000    117439.000000      117439.000000
# mean         239.207410        341.118181       123.404934         202.949446
# std          218.846634        277.645430       119.203009         168.294581
# min            0.000000          0.000000         0.000000           0.000000
# 25%           80.000000        202.000000        48.000000         111.000000
# 50%          176.000000        202.000000        65.000000         111.000000
# 75%          333.000000        425.000000       165.000000         260.000000
# max         1570.000000       2775.000000      1310.000000        1509.000000
#
#        Total main workers  Male main workers  Female main workers  \
# count       117439.000000      117439.000000        117439.000000
# mean           450.344630         265.758079           184.586551
# std            358.600844         211.307411           161.339450
# min              0.000000           0.000000             0.000000
# 25%            182.000000         110.000000            61.000000
# 50%            363.000000         212.000000           146.000000
# 75%            629.000000         369.000000           263.000000
# max           2174.000000        2002.000000          1103.000000
#
#        Total non workers  Male non workers  Female non workers
# count      117439.000000     117439.000000       117439.000000
# mean          507.021373        237.114647          269.906726
# std           415.894529        189.707613          232.467529
# min             0.000000          0.000000            0.000000
# 25%           205.000000         98.000000          105.000000
# 50%           396.000000        187.000000          205.000000
# 75%           695.000000        327.000000          366.000000
# max          2689.000000       1632.000000         1660.000000

# %%
df.to_csv("MHA_population_Final.csv")

# %%
df.to_csv("Final_MHA_pop.csv")
